# %% [markdown]
# 📋 1. Cabeçalho
# - 🗂️ | Exploração Inicial de Arquivos JSON/CSV
# - Propósito: entender a estrutura dos dados das empresas A e B lendo os arquivos brutos e inspecionando campos-chave
# - Tecnologia: Python 3.x (notebook Jupyter, bibliotecas padrão `json` e `csv`)
# - Contexto: notebook `notebooks/data_explorer.ipynb` do projeto `pipeline_dados`
#
# ⚡ 2. Funcionamento Rápido
# - O que faz: demonstra como abrir, ler e converter arquivos JSON e CSV das empresas A e B em estruturas Python para inspeção rápida
# - Como funciona:
#   1. Define caminhos relativos para os arquivos `../data_raw/dados_empresaA.json` e `../data_raw/dados_empresaB.csv`.
#   2. Lê o JSON linha a linha para checagem inicial e depois usa `json.load` para obter uma lista de dicionários.
#   3. Consulta itens específicos do JSON para validar chaves e tipos.
#   4. Lê o CSV como texto cru e extrai linhas específicas.
#   5. Constrói representações estruturadas do CSV com `csv.reader` (lista de listas) e `csv.DictReader` (lista de dicionários).
# - Entrada → Saída: arquivos JSON/CSV da pasta `data_raw` → objetos Python (`list`, `dict`, `str`) prontos para análise manual
#
# 🔧 3. Componentes Principais
# - Variáveis `path_json` e `path_csv`: armazenam caminhos relativos esperados `../data_raw/...`
# - Bloco `with open(path_json, 'r')`: leitura inicial do JSON e carregamento completo com `json.load(file)`; produz `list[dict]`
# - Bloco `with open(path_csv, 'r')`: inspeção textual do CSV para validar delimitadores e cabeçalhos
# - Loop com `csv.reader(..., delimiter=',')`: converte linhas em listas de campos (`list[list[str]]`)
# - Loop com `csv.DictReader(..., delimiter=',')`: converte linhas em dicionários mapeando cabeçalhos a valores (`list[dict[str,str]]`)
# - Acessos exemplificativos `dados_json[0]['Quantidade em Estoque']` e `dados_csv[1][3]`: validam presença de colunas críticas
#
# 📦 4. Dependências
# - `json`: carregar o arquivo JSON em objetos Python estruturados
# - `csv`: iterar e converter o CSV para listas ou dicionários
# - Estrutura esperada: arquivos devem existir em `../data_raw/` em relação ao notebook; cabeçalhos do CSV precisam estar definidos para o `DictReader`
#
# ▶️ 5. Como Usar
# - Pré-requisitos: Python 3 com suporte a Jupyter; arquivos `dados_empresaA.json` e `dados_empresaB.csv` acessíveis no caminho indicado
# - Execução: abrir o notebook em JupyterLab/Jupyter Notebook e rodar as células sequencialmente
# - Exemplo prático: após executar todas as células, use `dados_csv[0]['Produto']` (com `DictReader`) para consultar rapidamente o nome do primeiro produto
#
# 💡 6. Notas Técnicas
# - Padrões aplicados: leitura idempotente via contexto `with`; conversão explícita para `list`/`dict` para facilitar depuração
# - Melhorias possíveis:
#   1. Adicionar validação da existência dos arquivos e tratamento de exceções (`FileNotFoundError`, `json.JSONDecodeError`).
#   2. Encapsular leituras em funções reutilizáveis para uso em outros notebooks.
#   3. Incluir visualização resumida (ex.: `pandas.DataFrame.head()`) para facilitar inspeção tabular.

# %% [markdown]
# Lendo os dados

# %%
path_json = '../data_raw/dados_empresaA.json'

# %%
with open(path_json, 'r') as file:
    print(file.readline())
# Out:
# [{"Nome do Produto":"Blush em p\u00f3","Categoria do Produto":"Eletrodom\u00e9sticos","Pre\u00e7o do Produto (R$)":79.41,"Quantidade em Estoque":7,"Filial":"Filial 7"},

# %%
with open(path_json, 'r') as file:
    dados = file.readline()

# %%
dados
# Out:
# '[{"Nome do Produto":"Blush em p\\u00f3","Categoria do Produto":"Eletrodom\\u00e9sticos","Pre\\u00e7o do Produto (R$)":79.41,"Quantidade em Estoque":7,"Filial":"Filial 7"},\n'

# %%
type(dados)
# Out:
# str

# %%
dados[10]
# Out:
# ' '

# %%
import json

# %%
with open(path_json, 'r') as file:
    dados_json = json.load(file)

# %%
dados_json[0]
# Out:
# {'Nome do Produto': 'Blush em pó',
#  'Categoria do Produto': 'Eletrodomésticos',
#  'Preço do Produto (R$)': 79.41,
#  'Quantidade em Estoque': 7,
#  'Filial': 'Filial 7'}

# %%
dados_json[1]
# Out:
# {'Nome do Produto': 'Lápis de sobrancelha',
#  'Categoria do Produto': 'Eletrodomésticos',
#  'Preço do Produto (R$)': 85.47,
#  'Quantidade em Estoque': 78,
#  'Filial': 'Filial 8'}

# %%
type(dados_json)
# Out:
# list

# %%
type(dados_json[0])
# Out:
# dict

# %%
path_csv = '../data_raw/dados_empresaB.csv'

# %%
with open(path_csv, 'r') as file:
    print(file.readlines())
# Out:
# ['Nome do Item,Classificação do Produto,Valor em Reais (R$),Quantidade em Estoque,Nome da Loja,Data da Venda\n', 'Lápis de sobrancelha,Roupas,55.17,62,Filial 1,2023-04-13 18:58:06.794203\n', 'Batom matte,Eletrônicos,74.15,48,Filial 9,2023-06-03 18:58:06.794203\n', 'Corretivo,Roupas,54.86,36,Filial 5,2023-06-08 18:58:06.794203\n', 'Delineador líquido,Roupas,91.29,1,Filial 8,2023-02-27 18:58:06.794203\n', 'Batom líquido,Roupas,44.65,52,Filial 2,2022-09-05 18:58:06.794203\n', 'Base líquida,Eletrônicos,5.22,85,Filial 3,2022-09-11 18:58:06.794203\n', 'Máscara de cílios,Eletrônicos,1.08,31,Filial 6,2023-02-08 18:58:06.794203\n', 'Corretivo,Alimentos,56.22,76,Filial 5,2022-12-08 18:58:06.794203\n', 'Batom matte,Roupas,94.01,7,Filial 2,2023-07-18 18:58:06.794203\n', 'Lápis de sobrancelha,Alimentos,51.38,4,Filial 10,2023-06-19 18:58:06.794203\n', 'Pó compacto,Eletrônicos,5.59,82,Filial 10,2023-07-19 18:58:06.794203\n', 'Pó compacto,Eletrônicos,2.65,8,Filial 3,2023-05-24 18:58:06.794203\n', 'C
# ...

# %%
with open(path_csv, 'r') as file:
    print(file.readlines()[1])
# Out:
# Lápis de sobrancelha,Roupas,55.17,62,Filial 1,2023-04-13 18:58:06.794203

# %%
with open(path_csv, 'r') as file:
    dados_csv = file.readlines()

# %%
dados_csv[2]
# Out:
# 'Batom matte,Eletrônicos,74.15,48,Filial 9,2023-06-03 18:58:06.794203\n'

# %%
import csv

# %%
dados_csv = []
with open(path_csv, 'r') as file:
    spamreader = csv.reader(file, delimiter=',')
    for row in spamreader:
        dados_csv.append(row)

# %%
dados_csv[0][1]
# Out:
# 'Classificação do Produto'

# %%
type(dados_csv)
# Out:
# list

# %%
type(dados_csv[0])
# Out:
# list

# %%
dados_json[0]['Quantidade em Estoque']
# Out:
# 7

# %%
dados_csv[1][3]
# Out:
# '62'

# %%
dados_csv = []
with open(path_csv, 'r') as file:
    spamreader = csv.DictReader(file, delimiter=',')
    for row in spamreader:
        dados_csv.append(row)

dados_csv
# Out:
# [{'Nome do Item': 'Lápis de sobrancelha',
#   'Classificação do Produto': 'Roupas',
#   'Valor em Reais (R$)': '55.17',
#   'Quantidade em Estoque': '62',
#   'Nome da Loja': 'Filial 1',
#   'Data da Venda': '2023-04-13 18:58:06.794203'},
#  {'Nome do Item': 'Batom matte',
#   'Classificação do Produto': 'Eletrônicos',
#   'Valor em Reais (R$)': '74.15',
#   'Quantidade em Estoque': '48',
#   'Nome da Loja': 'Filial 9',
#   'Data da Venda': '2023-06-03 18:58:06.794203'},
#  {'Nome do Item': 'Corretivo',
#   'Classificação do Produto': 'Roupas',
#   'Valor em Reais (R$)': '54.86',
#   'Quantidade em Estoque': '36',
#   'Nome da Loja': 'Filial 5',
#   'Data da Venda': '2023-06-08 18:58:06.794203'},
#  {'Nome do Item': 'Delineador líquido',
#   'Classificação do Produto': 'Roupas',
#   'Valor em Reais (R$)': '91.29',
#   'Quantidade em Estoque': '1',
#   'Nome da Loja': 'Filial 8',
#   'Data da Venda': '2023-02-27 18:58:06.794203'},
#  {'Nome do Item': 'Batom líquido',
# ...

# %%
nome_colunas_json = list(dados_json[0].keys())

nome_colunas_json
# Out:
# ['Nome do Produto',
#  'Categoria do Produto',
#  'Preço do Produto (R$)',
#  'Quantidade em Estoque',
#  'Filial']

# %%
len(nome_colunas_json)
# Out:
# 5

# %%
nome_colunas_csv = list(dados_csv[0].keys())

nome_colunas_csv
# Out:
# ['Nome do Item',
#  'Classificação do Produto',
#  'Valor em Reais (R$)',
#  'Quantidade em Estoque',
#  'Nome da Loja',
#  'Data da Venda']

# %%
len(nome_colunas_csv)
# Out:
# 6

# %%
nome_colunas_json = list(dados_json[0].keys())
nome_colunas_csv = list(dados_csv[0].keys())

print(nome_colunas_json)
print(nome_colunas_csv)
# Out:
# ['Nome do Produto', 'Categoria do Produto', 'Preço do Produto (R$)', 'Quantidade em Estoque', 'Filial']
# ['Nome do Item', 'Classificação do Produto', 'Valor em Reais (R$)', 'Quantidade em Estoque', 'Nome da Loja', 'Data da Venda']

# %%
key_mapping = {'Nome do Item': 'Nome do Produto',
               'Classificação do Produto': 'Categoria do Produto',
               'Valor em Reais (R$)': 'Preço do Produto',
               'Quantidade em Estoque': 'Quantidade em Estoque',
               'Nome da Loja': 'Filial',
                'Data da Venda': 'Data da Venda'
              }

key_mapping
# Out:
# {'Nome do Item': 'Nome do Produto',
#  'Classificação do Produto': 'Categoria do Produto',
#  'Valor em Reais (R$)': 'Preço do Produto',
#  'Quantidade em Estoque': 'Quantidade em Estoque',
#  'Nome da Loja': 'Filial',
#  'Data da Venda': 'Data da Venda'}

# %%
new_dados_csv = []

for old_dict in dados_csv:
    dict_temp = {}
    for old_key, value in old_dict.items():
        dict_temp[key_mapping[old_key]] = value
    new_dados_csv.append(dict_temp)

new_dados_csv[0]
# Out:
# {'Nome do Produto': 'Lápis de sobrancelha',
#  'Categoria do Produto': 'Roupas',
#  'Preço do Produto': '55.17',
#  'Quantidade em Estoque': '62',
#  'Filial': 'Filial 1',
#  'Data da Venda': '2023-04-13 18:58:06.794203'}

# %%
dados_csv[0]
# Out:
# {'Nome do Item': 'Lápis de sobrancelha',
#  'Classificação do Produto': 'Roupas',
#  'Valor em Reais (R$)': '55.17',
#  'Quantidade em Estoque': '62',
#  'Nome da Loja': 'Filial 1',
#  'Data da Venda': '2023-04-13 18:58:06.794203'}

# %%
len(dados_json)
# Out:
# 3123

# %%
len(new_dados_csv)
# Out:
# 1323

# %%
3123 + 1323
# Out:
# 4446

# %%
combined_list = []
combined_list.extend(dados_json)
combined_list.extend(new_dados_csv)
# Out:
# {'Nome do Produto': 'Blush em pó',
#  'Categoria do Produto': 'Eletrodomésticos',
#  'Preço do Produto (R$)': 79.41,
#  'Quantidade em Estoque': 7,
#  'Filial': 'Filial 7'}

# %%
len(combined_list)
# Out:
# 4446

# %%
combined_list[0]
# Out:
# {'Nome do Produto': 'Blush em pó',
#  'Categoria do Produto': 'Eletrodomésticos',
#  'Preço do Produto (R$)': 79.41,
#  'Quantidade em Estoque': 7,
#  'Filial': 'Filial 7'}

# %%
dados_json[0]
# Out:
# {'Nome do Produto': 'Blush em pó',
#  'Categoria do Produto': 'Eletrodomésticos',
#  'Preço do Produto (R$)': 79.41,
#  'Quantidade em Estoque': 7,
#  'Filial': 'Filial 7'}

# %%
combined_list[4445]
# Out:
# {'Nome do Produto': 'Sombra de olhos',
#  'Categoria do Produto': 'Eletrônicos',
#  'Preço do Produto': '41.73',
#  'Quantidade em Estoque': '5',
#  'Filial': 'Filial 6',
#  'Data da Venda': '2022-11-21 18:58:06.794203'}

# %%
new_dados_csv[-1]
# Out:
# {'Nome do Produto': 'Sombra de olhos',
#  'Categoria do Produto': 'Eletrônicos',
#  'Preço do Produto': '41.73',
#  'Quantidade em Estoque': '5',
#  'Filial': 'Filial 6',
#  'Data da Venda': '2022-11-21 18:58:06.794203'}

# %%
nome_colunas = list(combined_list[0].keys())
nome_colunas
# Out:
# ['Nome do Produto',
#  'Categoria do Produto',
#  'Preço do Produto (R$)',
#  'Quantidade em Estoque',
#  'Filial']

# %%
path_dados_combinados = '../data_processed/dados_combinados.json'

with open(path_dados_combinados, 'w') as file:
    writer = csv.DictWriter(file, fieldnames=nome_colunas)
    writer.writeheader()

    for row in combined_list:
        writer.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 8
#       5 writer.writeheader()
#       7 for row in combined_list:
# ----> 8     writer.writerow(row)
#
# File /usr/lib/python3.10/csv.py:154, in DictWriter.writerow(self, rowdict)
#     153 def writerow(self, rowdict):
# --> 154     return self.writer.writerow(self._dict_to_list(rowdict))
#
# File /usr/lib/python3.10/csv.py:149, in DictWriter._dict_to_list(self, rowdict)
#     147     wrong_fields = rowdict.keys() - self.fieldnames
#     148     if wrong_fields:
# --> 149         raise ValueError("dict contains fields not in fieldnames: "
#     150                          + ", ".join([repr(x) for x in wrong_fields]))
#     151 return (rowdict.get(key, self.restval) for key in self.fieldnames)
#
# ValueError: dict contains fields not in fieldnames: 'Data da Venda', 'Preço do Produto'

# %%
combined_list[0]
# Out:
# {'Nome do Produto': 'Blush em pó',
#  'Categoria do Produto': 'Eletrodomésticos',
#  'Preço do Produto (R$)': 79.41,
#  'Quantidade em Estoque': 7,
#  'Filial': 'Filial 7'}

# %%
combined_list[-1]
# Out:
# {'Nome do Produto': 'Sombra de olhos',
#  'Categoria do Produto': 'Eletrônicos',
#  'Preço do Produto': '41.73',
#  'Quantidade em Estoque': '5',
#  'Filial': 'Filial 6',
#  'Data da Venda': '2022-11-21 18:58:06.794203'}

# %%
combined_list[0]['Nome do Produto']
# Out:
# 'Blush em pó'

# %%
combined_list[-1]['Nome do Produto']
# Out:
# 'Sombra de olhos'

# %%
combined_list[-1]['Data da Venda']
# Out:
# '2022-11-21 18:58:06.794203'

# %%
combined_list[0]['Data da Venda']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 combined_list[0]['Data da Venda']
#
# KeyError: 'Data da Venda'

# %%
combined_list[0].get('Data da Venda')

# %%
combined_list[-1].get('Data da Venda')
# Out:
# '2022-11-21 18:58:06.794203'

# %%
combined_list[0].get('Data da Venda', 'Indisponível')
# Out:
# 'Indisponível'
